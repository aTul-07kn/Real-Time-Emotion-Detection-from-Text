# %%
import re
import nltk
import numpy as np
import pandas as pd
from keras.layers import *
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from keras.utils import to_categorical
from nltk.tokenize import word_tokenize
from keras.models import Sequential,Model
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense,Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential, load_model
from sklearn.preprocessing import OneHotEncoder
from nltk.stem.lancaster import LancasterStemmer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, GRU, LSTM, Bidirectional, Embedding, Dropout

# %%
df=pd.read_excel('/content/Own_Amazon_AddedRows(Final).xlsx')
df.head()
anger_count = len(df[df['emotion'] == 'Angry'])
fear_count = len(df[df['emotion'] == 'Disgusted'])
joy_count = len(df[df['emotion'] == 'Happy'])
sadness_count = len(df[df['emotion'] == 'Sad'])

print("Number of rows with sentiment 'Angry':", anger_count)

print("Number of rows with sentiment 'Disgusted':", fear_count)

print("Number of rows with sentiment 'Happy':", joy_count)

print("Number of rows with sentiment 'Sad':", sadness_count)
# Out:
# Number of rows with sentiment 'Angry': 3902
# Number of rows with sentiment 'Disgusted': 4580
# Number of rows with sentiment 'Happy': 4661
# Number of rows with sentiment 'Sad': 3042

# %%
Sentences = df['review'].astype(str)
Sentiments = df['emotion'].astype(str)

# %%
glove ='glove.6B.50d.txt'

def load_glove_embeddings(path):
    embeddings_index = {}
    with open(path, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
    return embeddings_index

Glove = load_glove_embeddings(glove)

# %%
def cosine_similarity(a, b):
    """
    Computes the cosine similarity between two vectors a and b.
    """
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
import tensorflow as tf

def preprocess(Sentences):
    sentences = tf.strings.substr(Sentences, 0, 300)
    sentences = tf.strings.regex_replace(sentences, b"<br\\s*/?>", b" ")
    sentences = tf.strings.regex_replace(sentences, b"[^a-zA-Z']", b" ")
    sentences = tf.strings.split(sentences)
    sentences = tf.strings.lower(sentences)
    sentences = sentences.to_tensor(default_value=b"<pad>")
    return sentences

# %%
sentences = preprocess(Sentences)
sentences.shape
# Out:
# TensorShape([16185, 72])

# %%
def encoding(sentences, Glove):
    Encoded_vec = []
    for sentence in sentences:
        sent_vec = []
        for token in sentence:
            token = token.numpy().decode('utf-8')
            if token in Glove:
                sent_vec.append(Glove[token])
            else:
                sent_vec.append(np.zeros(50))
        Encoded_vec.append(sent_vec)
    return Encoded_vec

# %%
Encoded_vec = encoding(sentences, Glove)
X = np.array(Encoded_vec)
print(X.shape)
# Out:
# (16185, 72, 50)

# %%
enc = OneHotEncoder(handle_unknown='ignore')
Y = enc.fit_transform(np.array(Sentiments).reshape(-1,1)).toarray()
print(Y.shape)
# Out:
# (16185, 4)

# %%
from keras.layers import Embedding
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=23)

# %%
# -----------------------------1st try---------------------------------------
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, Dense

# # Defining the BiLSTM Model
# class BiLSTMModel:
#     def __init__(self):
#         self.model = Sequential()
#         self.model.add(Bidirectional(LSTM(150, input_shape=(100, 50))))  # Increase units in LSTM
#         self.model.add(Dropout(0.5))  # Increase dropout
#         self.model.add(Dense(4, activation='softmax'))
#         self.model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

#     def fit(self, X_train, Y_train, X_val, Y_val, epochs, batch_size):
#         history = self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, Y_val))
#         return history  # Return the training history for later visualization

#     def evaluate(self, X, Y, batch_size):
#         return self.model.evaluate(X, Y, batch_size=batch_size)

#     def predict(self, X):
#         return self.model.predict(X)

# --------------------------------------------2nd try----------------------------------------------
from tensorflow.keras.callbacks import EarlyStopping

class BiLSTMModel:
    def __init__(self):
        self.model = Sequential()
        self.model.add(Bidirectional(LSTM(256, input_shape=(X_train.shape[1], X_train.shape[2]))))  # Increase LSTM units
        self.model.add(Dropout(0.2))  # Reduce dropout rate
        self.model.add(Dense(4, activation='softmax'))
        self.model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

    def fit(self, X_train, Y_train, X_val, Y_val, epochs, batch_size):
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        history = self.model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,
                                 validation_data=(X_val, Y_val), callbacks=[early_stopping])
        return history

    def evaluate(self, X, Y, batch_size):
        return self.model.evaluate(X, Y, batch_size=batch_size)

    def predict(self, X):
        return self.model.predict(X)

# %%
# Create an instance of the BiLSTMModel class
model = BiLSTMModel()

# Train the model
history = model.fit(X_train, Y_train, X_test, Y_test, epochs=20, batch_size=64)

# Save the trained model
model.model.save('20epochs_improved_Amazon_dataset.h5')
# Out:
# Epoch 1/20
# 203/203 [==============================] - 146s 688ms/step - loss: 1.0691 - accuracy: 0.5443 - val_loss: 1.0236 - val_accuracy: 0.5604
# Epoch 2/20
# 203/203 [==============================] - 139s 681ms/step - loss: 0.9352 - accuracy: 0.5997 - val_loss: 0.9409 - val_accuracy: 0.6067
# Epoch 3/20
# 203/203 [==============================] - 138s 679ms/step - loss: 0.8911 - accuracy: 0.6145 - val_loss: 0.9176 - val_accuracy: 0.6157
# Epoch 4/20
# 203/203 [==============================] - 138s 678ms/step - loss: 0.8409 - accuracy: 0.6394 - val_loss: 0.8814 - val_accuracy: 0.6302
# Epoch 5/20
# 203/203 [==============================] - 138s 678ms/step - loss: 0.8083 - accuracy: 0.6578 - val_loss: 0.8612 - val_accuracy: 0.6330
# Epoch 6/20
# 203/203 [==============================] - 138s 679ms/step - loss: 0.7772 - accuracy: 0.6677 - val_loss: 0.8648 - val_accuracy: 0.6299
# Epoch 7/20
# 203/203 [==============================] - 164s 811ms/step - loss: 0.7474 - accuracy: 0.6870 - val_loss: 0.8501 - val_accuracy: 0.6361
# Epoch 8/20
# 203/203 [==============================] - 144s 708ms/step - loss: 0.7226 - accuracy: 0.6945 - val_loss: 0.8523 - val_accuracy: 0.6441
# Epoch 9/20
# 203/203 [==============================] - 151s 743ms/step - loss: 0.6992 - accuracy: 0.7022 - val_loss: 0.8897 - val_accuracy: 0.6281
# Epoch 10/20
# 203/203 [==============================] - 138s 679ms/step - loss: 0.6771 - accuracy: 0.7154 - val_loss: 0.8716 - val_accuracy: 0.6416

# %%
Loss, acc = model.evaluate(X_test, Y_test, batch_size=64)
print("Loss: %.2f" % (Loss))
print("Accuracy: %.2f" % (acc))
# Out:
# 51/51 [==============================] - 9s 176ms/step - loss: 0.8501 - accuracy: 0.6361
# Loss: 0.85
# Accuracy: 0.64

# %%
model.model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (None, 512)              628736
#  nal)
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 630,788
# Trainable params: 630,788
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
history=history

# Assuming history contains the training history
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Now you can also generate a confusion matrix using the test data
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get predictions on the test data
Y_pred = model.predict(X_test)

# Convert predictions and true labels back from one-hot encoding
Y_pred_labels = np.argmax(Y_pred, axis=1)
Y_true_labels = np.argmax(Y_test, axis=1)

# Create confusion matrix
conf_matrix = confusion_matrix(Y_true_labels, Y_pred_labels)

# Visualize the confusion matrix using seaborn
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=enc.categories_[0], yticklabels=enc.categories_[0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 102/102 [==============================] - 22s 190ms/step

# %%
from tensorflow.keras.utils import plot_model
plot_model(model.model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming 'emotion' and 'review' are columns in your DataFrame 'df'
sentiments = df['emotion'].unique()

fig, axes = plt.subplots(2, 2, figsize=(10, 10))

for ax, sentiment in zip(axes.flatten(), sentiments):
    # Convert 'review' column to strings and join
    text = " ".join(df[df['emotion'] == sentiment]['review'].astype(str))
    cloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(text)

    # Set emotion as the title for each subplot
    ax.set_title(sentiment)

    # Display word cloud
    ax.imshow(cloud)
    ax.axis("off")  # Remove axis labels and ticks

plt.show()

# %%
#Emotion Count in graphical format
import seaborn as sns
sentiment = df['emotion'].value_counts()
sentiment_order = list(sentiment.index)

plt.figure(figsize=(15,8))

ax = sns.countplot(x='emotion', data=df, order=sentiment_order)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f"{height}", (p.get_x() + p.get_width() / 2., height), ha='center', va='bottom', fontsize=10)

plt.show;

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sentiment_order = df['emotion'].unique()
df['content_len'] = df['review'].apply(lambda x: len(str(x)) if pd.notna(x) else 0)

# Table
sentiment_grouped_mean_len = df.groupby('emotion')['content_len'].mean()
sgmlen_transpose = sentiment_grouped_mean_len.to_frame().transpose()

# Barplot
plt.figure(figsize=(15, 8))

ax = sns.barplot(data=df, x='emotion', y='content_len', estimator=np.mean, order=sentiment_order)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, -50),
                textcoords='offset points')

plt.show()


#------------------------------------------------------------
#The below code is for content_word
df['content_word'] = df['review'].apply(lambda x: len(x.split()) if pd.notna(x) else 0)

# table
sentiment_grouped_mean_word = df.groupby('emotion')['content_word'].mean()
sgmword_transpose = sentiment_grouped_mean_word.to_frame().transpose()

# barplot
plt.figure(figsize=(15,8))

ax = sns.barplot(data=df, x='emotion', y='content_word', estimator=np.mean, order=sentiment_order)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, -50),
                textcoords = 'offset points')

plt.show;

# %%
#Graphical representation of content_wor,content_len

fig, ax = plt.subplots(1, 2, figsize=(20, 6))

sns.kdeplot(x=df['content_len'], hue=df['emotion'], ax=ax[0], label='content len', legend=False)
ax[0].set_title('Distribution of Content Length by Emotion')
sns.kdeplot(x=df['content_word'], hue=df['emotion'], ax=ax[1], label='content word')
ax[1].set_title('Distribution of Content Word Count by Emotion')

plt.show()

# %%
while True:

  i=input("Enter : ")
  twt = [i]
  #Next, tokenize it.
  Twt = preprocess(twt)

  # Encoding
  Twt = encoding(Twt, Glove)
  Twt = np.array(Twt)
  print(Twt.shape)
  #Predict the sentiment by passing the sentence to the model we built.
  sentiment = model.predict(Twt)[0]
  label = np.argmax(sentiment)
  print(enc.categories_[0][label])
# Out:
# Enter : Everything is fine and it works perfectly for me
# (1, 9, 50)
# 1/1 [==============================] - 2s 2s/step
# Happy
# Enter : One of the screens was cracked,never got a response
# (1, 10, 50)
# 1/1 [==============================] - 0s 24ms/step
# Disgusted
# Enter : It just doesn't make a big deal so it doesn't work
# (1, 11, 50)
# 1/1 [==============================] - 0s 24ms/step
# Sad
# Enter : This screen protector is perfect. I ran the hot water in the bathroom to get it a little steamy to reduce dust in the air. I placed the guide on my phone, used the dust stickers to get every last speck of dust removed from my screen, pulled the protector from the styrofoam, removed the film, and quickly set it on my phone. Absolutely perfect. The guide is awesome. No dust and there was just one small bubble that I had to press out. I gently pressed the edges down and I could not be more satisfied. THANK YOU!
# (1, 58, 50)
# 1/1 [==============================] - 0s 59ms/step
# Happy
# Enter : Man this thing is easy to install. Went on flawlessly and I didn't screw up the first one as I typically do. Have been very pleased with the protector though I did find one small scratch on it the other day and have no idea how it got there. Not the end of the world. I'd use them again.
# (1, 59, 50)
# 1/1 [==============================] - 0s 32ms/step
# Disgusted
# Enter : Purchased for my iPhone 15 Pro and fitment is perfect. The only issue I had was with the template, while installing the screen protector, the template got in the way so I had to push the screen protector through and carefully lift the template so it would not lift the screen protector.
# (1, 51, 50)
# 1/1 [==============================] - 0s 32ms/step
# Happy
# Enter : The installation frame is 100% going to change your protective glass game. I got my phone clean using the enclosed wipes, put the frame on, and now have a *flawless* protector on my screen. No bubbles, no debris taunting me. Absolutely the easiest installation experience I’ve ever had for a screen protector.
# (1, 51, 50)
# 1/1 [==============================] - 0s 34ms/step
# Happy
# Enter : When I first got them, they looked very strong. If you are someone that just needs it for that rare fall this may be for you. If you drop your phone often or place it down randomly I wouldn’t recommend it. I have yet to drop my phone with it on but I will say, they scratch very easily! To the point that you’ll need to change it out because of the scratches.
# (1, 63, 50)
# 1/1 [==============================] - 0s 34ms/step
# Sad
# Enter : I’ve been using this screen protector for exactly 6 weeks, and it has already cracked in the upper right hand corner. I didn’t drop my phone so I have no idea why it cracked. Thankfully it came with 3 protectors so I’m going to replace it and hope it won’t crack again. I don’t know why there are so many good reviews. I will not be repurchasing this brand again.
# (1, 60, 50)
# 1/1 [==============================] - 0s 34ms/step
# Disgusted
# Enter : I am pretty gentle with my phone and never had a screen protector crack at all, this brand cracked on one edge after sitting in my back back.for a short period. Phone wasn't dropped at all. This happened on the 9th day, the phone has a solid protective cover as well.... I am trying the 2nd screen cover & hope this will last longer.
# (1, 59, 50)
# 1/1 [==============================] - 0s 32ms/step
# Disgusted
# Enter : The only reason I’m not returning this is because I already put the camera protector on but omg I opened the first screen… just a red sticker no perky screen came off. Okay so I tried seeing if maybe the red sticker wasn’t working and I had to manually peel it. Nope just a plain glass screen. Tried the next one. Same thing. I was really hoping the third one would be my lucky screen but nope!!! I already ordered a different brand of screen protectors and will just take my loss.
# (1, 59, 50)
# 1/1 [==============================] - 0s 34ms/step
# Disgusted
# Enter : I have bought a 3 pack twice thinking maybe the first few were just crappy, but the second 3 pack i got is the same. Any little scratch will cause a crack in the tempered screen. If i put it in the same pockets as my keys the tempered screen gets scratched up easily. I have had tempered screens before and that has never happened. Don’t recommend these. I guess for the price, you get what you get.
# (1, 58, 50)
# 1/1 [==============================] - 0s 32ms/step
# Sad
# Enter : I have an app that shows charging speed/watt. Per that app the speed shows the same as the little Apple cube. I confirmed this by noting the charge speed with a Apple 20w charger, that showed a faster charge than this item. Bought this to save money. Looks like I wasted time and money for this charger that doesnt work any better than the small apple cube. So far it hasnt damaged my iphone13, but based on the performance, I dont trust this device. I wont be using this anymore. Im going to paint it black and let my son play hockey with it.
# (1, 58, 50)
# 1/1 [==============================] - 0s 64ms/step
# Disgusted
# Enter : I bought this charger for both my Apple Watch and my iPhone. The cube itself works with the Apple Watch charging cord, but it is very sensitive and if I move it the wrong way it stops charging. The phone cord it came with doesn’t go all the way into the cube and it won’t charge at all. Wish I could return but I already got rid of the packaging.
# (1, 63, 50)
# 1/1 [==============================] - 0s 33ms/step
# Disgusted
# Enter : This product doesn’t last at all. I have only used this for about 2 months and it has stop charging already. I just recently took it out the box since I purchased it. The cord still looks new. Bad product. I’m using the second one now not sure how long that one is going to last.
# (1, 57, 50)
# 1/1 [==============================] - 0s 43ms/step
# Sad
# Enter : The iPad was defective or damaged.
# (1, 6, 50)
# 1/1 [==============================] - 0s 22ms/step
# Angry
# Enter : Excellent Quality product from Apple's Ordered Yellow but Supplier Fraudulent and sent me Golden colour
# (1, 15, 50)
# 1/1 [==============================] - 0s 25ms/step
# Happy
# Enter : Selfie camera is not a good quality and screen area is also reduced by black boundary. Speed seems as well slow
# (1, 21, 50)
# 1/1 [==============================] - 0s 28ms/step
# Disgusted
# Enter : Worst product lacking in gaming bad for students and people I suggest Amazon to stop from taking apple products Very bad
# (1, 21, 50)
# 1/1 [==============================] - 0s 26ms/step
# Disgusted
# Enter : Over priced a lot !! Not even worth a penny for this amount you can get a iPad air 5th gen
# (1, 20, 50)
# 1/1 [==============================] - 0s 26ms/step
# Sad
# Enter : Loved it good for playing time with kids during spare time.Sound clarity is good and speaker volume is soothing.
# (1, 20, 50)
# 1/1 [==============================] - 0s 23ms/step
# Happy
# Enter : Much better than the regular Chinese stuff available at a much cheaper price, finishing is quite good and performance is satisfactory.
# (1, 21, 50)
# 1/1 [==============================] - 0s 25ms/step
# Happy
# Enter : Great product looks well built, wish the instructions were a lot clearer with a link to instructions video and using it as a mic with speaker
# (1, 26, 50)
# 1/1 [==============================] - 0s 27ms/step
# Happy
# Enter : Let me tell you from my experience, it is not worth a penny, no one should buy just after seeing the advertisement. My experience with the series is what I would say is a poor quality product
# (1, 37, 50)
# 1/1 [==============================] - 0s 30ms/step
# Sad
# Enter : Voice lagging issue, not suitable for singing, seems like kids mic. rate is higher. cheap product.
# (1, 16, 50)
# 1/1 [==============================] - 0s 27ms/step
# Disgusted
# Enter : I just bought this product and it's sound quality is pathetic. Don't be fooled by inflated ratings. Also this product is non - returnable and can only be replaced. So, don't fall for the trap. It says it has a vocal cancellation feature but it works only for a few seconds and then disappears.
# (1, 53, 50)
# 1/1 [==============================] - 0s 41ms/step
# Sad
# Enter : TOTALLY USELESS
# (1, 2, 50)
# 1/1 [==============================] - 0s 25ms/step
# Disgusted
# Enter : Worst Product with worst Customer experience, within 24 hours Amazon team want me to visit Service center
# (1, 16, 50)
# 1/1 [==============================] - 0s 45ms/step
# Angry
# Enter : Stupid design the microphone and speaker ate close to each other. As a result the singer thinks they are singing loudly but actually those around do not hear anything
# (1, 29, 50)
# 1/1 [==============================] - 0s 44ms/step
# Disgusted
# Enter : Not worth it and no service back up
# (1, 8, 50)
# 1/1 [==============================] - 0s 45ms/step
# Disgusted
# Enter : Not a good product, it gives more echo the sound quality is bad and is not clear.
# (1, 17, 50)
# 1/1 [==============================] - 0s 25ms/step
# Sad
# Enter : The Voice volume is very less , it is a speaker than what is the use of it
# (1, 17, 50)
# 1/1 [==============================] - 0s 54ms/step
# Disgusted
# Enter : Very costly and worst product. Mic quality is very poor. I strongly suggested never to buy this product. Useless
# (1, 19, 50)
# 1/1 [==============================] - 0s 25ms/step
# Sad
# Enter : Iam not happy with the battery backup
# (1, 7, 50)
# 1/1 [==============================] - 0s 28ms/step
# Disgusted
# Enter : 25
# (1, 0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-c6819639889c> in <cell line: 1>()
#      11   print(Twt.shape)
#      12   #Predict the sentiment by passing the sentence to the model we built.
# ---> 13   sentiment = model.predict(Twt)[0]
#      14   label = np.argmax(sentiment)
#      15   print(enc.categories_[0][label])
#
# <ipython-input-40-83cff733338f> in predict(self, X)
#      41
#      42     def predict(self, X):
# ---> 43         return self.model.predict(X)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#
#     ValueError: Exception encountered when calling layer 'sequential_10' (type Sequential).
#
#     Cannot iterate over a shape with unknown rank.
#
#     Call arguments received by layer 'sequential_10' (type Sequential):
#       • inputs=tf.Tensor(shape=<unknown>, dtype=float32)
#       • training=False
#       • mask=None

# %%
mo=load_model("/content/(balanced)20epochs_Own_Amazon.h5")

# %%
def get_emotion(i):
  twt = [i]
  #Next, tokenize it
  Twt = preprocess(twt)

  # Encoding
  Twt = encoding(Twt, Glove)
  Twt = np.array(Twt)
  print(Twt.shape)
  #Predict the sentiment by passing the sentence to the model we built.
  sentiment = mo.predict(Twt)[0]
  label = np.argmax(sentiment)
  return(enc.categories_[0][label])

# %%
print(get_emotion("Not helpful for taking classes"))
# Out:
# (1, 5, 50)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-f37940ac128e> in <cell line: 1>()
# ----> 1 print(get_emotion("Not helpful for taking classes"))
#
# <ipython-input-56-9504f3fbe60d> in get_emotion(i)
#       9   print(Twt.shape)
#      10   #Predict the sentiment by passing the sentence to the model we built.
# ---> 11   sentiment = mo.predict(Twt)[0]
#      12   label = np.argmax(sentiment)
#      13   return(enc.categories_[0][label])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_10" is incompatible with the layer: expected shape=(None, 72, 50), found shape=(None, 5, 50)
